# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
# !wget $data -O car-price-data.csv
# Out:
# --2023-10-02 18:09:02--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8002::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: 'car-price-data.csv'
#
#      0K .......... .......... .......... .......... ..........  3%  288K 5s
#     50K .......... .......... .......... .......... ..........  6%  418K 4s
#    100K .......... .......... .......... .......... .......... 10%  904K 3s
#    150K .......... .......... .......... .......... .......... 13% 2.02M 2s
#    200K .......... .......... .......... .......... .......... 17%  570K 2s
#    250K .......... .......... .......... .......... .......... 20% 1.31M 2s
#    300K .......... .......... .......... .......... .......... 24% 1.48M 2s
#    350K .......... .......... .......... .......... .......... 27% 1.74M 1s
#    400K .......... .......... .......... .......... .......... 31% 1.23M 1s
#    450K .......... .......... .......... .......... .......... 34% 1.44M 1s
#    500K .......... .......... .......... .......... .......... 38% 1.59M 1s
#    550K .......... .......... .......... .......... .......... 41% 1.73M 1s
#    600K .......... .......... .......... .......... .......... 45% 1.38M 1s
#    650K .......... .......... .......... .......... .......... 48% 1.85M 1s
#    700K .......... .......... .......... .......... .......... 52% 2.01M 1s
#    750K .......... .......... .......... .......... .......... 55% 1.78M 1s
#    800K .......... .......... .......... .......... .......... 58% 1.37M 1s
#    850K .......... .......... .......... .......... .......... 62% 2.15M 1s
#    900K .......... .......... .......... .......... .......... 65% 1.96M 0s
#    950K .......... .......... .......... .......... .......... 69% 1.41M 0s
#   1000K .......... .......... .......... .......... .......... 72% 2.22M 0s
#   1050K .......... .......... .......... .......... .......... 76% 2.10M 0s
#   1100K .......... .......... .......... .......... .......... 79% 2.05M 0s
#   1150K .......... .......... .......... .......... .......... 83% 1.52M 0s
#   1200K .......... .......... .......... .......... .......... 86% 1.37M 0s
#   1250K .......... .......... .......... .......... .......... 90% 2.04M 0s
#   1300K .......... .......... .......... .......... .......... 93% 1.04M 0s
#   1350K .......... .......... .......... .......... .......... 97% 1.73M 0s
#   1400K .......... .......... .......... ..........           100% 2.15M=1.2s
#
# 2023-10-02 18:09:04 (1.19 MB/s) - 'car-price-data.csv' saved [1475504/1475504]

# %%
data = pd.read_csv('car-price-data.csv')

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
features = ['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
'MSRP']

# %%
data = data[features]
data.columns= data.columns.str.lower().str.replace(' ', '_')

# %%
data.fillna(0, inplace=True)
# Out:
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\2227532753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)

# %%
data.rename(columns={'msrp': 'price'}, inplace=True)
# Out:
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\1422463015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'msrp': 'price'}, inplace=True)

# %%
data.head(50)
# Out:
#              make       model  year  engine_hp  engine_cylinders  \
# 0             BMW  1 Series M  2011      335.0               6.0
# 1             BMW    1 Series  2011      300.0               6.0
# 2             BMW    1 Series  2011      300.0               6.0
# 3             BMW    1 Series  2011      230.0               6.0
# 4             BMW    1 Series  2011      230.0               6.0
# 5             BMW    1 Series  2012      230.0               6.0
# 6             BMW    1 Series  2012      300.0               6.0
# 7             BMW    1 Series  2012      300.0               6.0
# 8             BMW    1 Series  2012      230.0               6.0
# 9             BMW    1 Series  2013      230.0               6.0
# 10            BMW    1 Series  2013      300.0               6.0
# 11            BMW    1 Series  2013      230.0               6.0
# 12            BMW    1 Series  2013      300.0               6.0
# 13            BMW    1 Series  2013      230.0               6.0
# 14            BMW    1 Series  2013      230.0               6.0
# 15            BMW    1 Series  2013      320.0               6.0
# 16            BMW    1 Series  2013      320.0               6.0
# 17           Audi         100  1992      172.0               6.0
# 18           Audi         100  1992      172.0               6.0
# 19           Audi         100  1992      172.0               6.0
# 20           Audi         100  1992      172.0               6.0
# 21           Audi         100  1992      172.0               6.0
# 22           Audi         100  1993      172.0               6.0
# 23           Audi         100  1993      172.0               6.0
# 24           Audi         100  1993      172.0               6.0
# 25           Audi         100  1993      172.0               6.0
# 26           Audi         100  1993      172.0               6.0
# 27           Audi         100  1994      172.0               6.0
# 28           Audi         100  1994      172.0               6.0
# 29           Audi         100  1994      172.0               6.0
# 30           Audi         100  1994      172.0               6.0
# 31           Audi         100  1994      172.0               6.0
# 32           FIAT  124 Spider  2017      160.0               4.0
# 33           FIAT  124 Spider  2017      160.0               4.0
# 34           FIAT  124 Spider  2017      160.0               4.0
# 35  Mercedes-Benz   190-Class  1991      130.0               4.0
# 36  Mercedes-Benz   190-Class  1991      158.0               6.0
# 37  Mercedes-Benz   190-Class  1992      158.0               6.0
# 38  Mercedes-Benz   190-Class  1992      130.0               4.0
# 39  Mercedes-Benz   190-Class  1993      130.0               4.0
# 40  Mercedes-Benz   190-Class  1993      158.0               6.0
# 41            BMW    2 Series  2016      240.0               4.0
# 42            BMW    2 Series  2016      240.0               4.0
# 43            BMW    2 Series  2016      320.0               6.0
# 44            BMW    2 Series  2016      240.0               4.0
# 45            BMW    2 Series  2016      240.0               4.0
# 46            BMW    2 Series  2016      320.0               6.0
# 47            BMW    2 Series  2016      240.0               4.0
# 48            BMW    2 Series  2016      320.0               6.0
# 49            BMW    2 Series  2016      320.0               6.0
#
#    transmission_type vehicle_style  highway_mpg  city_mpg  price
# 0             MANUAL         Coupe           26        19  46135
# 1             MANUAL   Convertible           28        19  40650
# 2             MANUAL         Coupe           28        20  36350
# 3             MANUAL         Coupe           28        18  29450
# 4             MANUAL   Convertible           28        18  34500
# 5             MANUAL         Coupe           28        18  31200
# 6             MANUAL   Convertible           26        17  44100
# 7             MANUAL         Coupe           28        20  39300
# 8             MANUAL   Convertible           28        18  36900
# 9             MANUAL   Convertible           27        18  37200
# 10            MANUAL         Coupe           28        20  39600
# 11            MANUAL         Coupe           28        19  31500
# 12            MANUAL   Convertible           28        19  44400
# 13            MANUAL   Convertible           28        19  37200
# 14            MANUAL         Coupe           28        19  31500
# 15            MANUAL   Convertible           25        18  48250
# 16            MANUAL         Coupe           28        20  43550
# 17            MANUAL         Sedan           24        17   2000
# 18            MANUAL         Sedan           24        17   2000
# 19         AUTOMATIC         Wagon           20        16   2000
# 20            MANUAL         Sedan           24        17   2000
# 21            MANUAL         Sedan           21        16   2000
# 22            MANUAL         Sedan           24        17   2000
# 23         AUTOMATIC         Wagon           20        16   2000
# 24            MANUAL         Sedan           24        17   2000
# 25            MANUAL         Sedan           24        17   2000
# 26            MANUAL         Sedan           21        16   2000
# 27         AUTOMATIC         Wagon           21        16   2000
# 28            MANUAL         Sedan           22        16   2000
# 29            MANUAL         Sedan           22        17   2000
# 30         AUTOMATIC         Sedan           22        16   2000
# 31         AUTOMATIC         Wagon           21        16   2000
# 32            MANUAL   Convertible           35        26  27495
# 33            MANUAL   Convertible           35        26  24995
# 34            MANUAL   Convertible           35        26  28195
# 35            MANUAL         Sedan           26        18   2000
# 36            MANUAL         Sedan           25        17   2000
# 37            MANUAL         Sedan           25        17   2000
# 38            MANUAL         Sedan           26        18   2000
# 39            MANUAL         Sedan           26        18   2000
# 40            MANUAL         Sedan           25        17   2000
# 41         AUTOMATIC         Coupe           35        23  32850
# 42         AUTOMATIC   Convertible           34        23  38650
# 43         AUTOMATIC   Convertible           31        20  48750
# 44         AUTOMATIC         Coupe           35        23  34850
# 45         AUTOMATIC   Convertible           34        22  40650
# 46         AUTOMATIC         Coupe           31        20  44150
# 47            MANUAL         Coupe           34        22  32850
# 48         AUTOMATIC         Coupe           30        20  46150
# 49         AUTOMATIC   Convertible           30        20  50750

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# price                  int64
# dtype: object

# %% [markdown]
# #### Question 1
# ##### What is the most frequent observation (mode) for the column transmission_type?

# %%
mode = data['transmission_type'].mode()
mode
# Out:
# 0    AUTOMATIC
# Name: transmission_type, dtype: object

# %% [markdown]
# #### Question 2
# #### Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features in the dataset.
#
# #### What are the two features that have the biggest correlation in this dataset?

# %%
numerical_features = ['year','engine_hp','engine_cylinders','highway_mpg','city_mpg']

# %%
numerical_data = data[numerical_features]

# %%
correlation_matrix = numerical_data.corr()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                       year  engine_hp  engine_cylinders  highway_mpg  city_mpg
# year              1.000000   0.338714         -0.040708     0.258240  0.198171
# engine_hp         0.338714   1.000000          0.774851    -0.415707 -0.424918
# engine_cylinders -0.040708   0.774851          1.000000    -0.614541 -0.587306
# highway_mpg       0.258240  -0.415707         -0.614541     1.000000  0.886829
# city_mpg          0.198171  -0.424918         -0.587306     0.886829  1.000000

# %%
max_correlation = correlation_matrix.abs().unstack().sort_values(ascending=False)
top_correlation = max_correlation[max_correlation < 1].idxmax()

print("\nFeatures with the highest correlation:")
print(top_correlation)
# Out:
# Features with the highest correlation:
# ('city_mpg', 'highway_mpg')

# %% [markdown]
# #### Make price binary

# %%
# Calculate the mean price
mean_price = data['price'].mean()
print(mean_price)
# Create the 'above_average' binary variable
data['above_average'] = (data['price'] > mean_price).astype(int)
data['above_average']
# Out:
# 40594.737032063116
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\1562395376.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['above_average'] = (data['price'] > mean_price).astype(int)
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 11909    1
# 11910    1
# 11911    1
# 11912    1
# 11913    0
# Name: above_average, Length: 11914, dtype: int32

# %%
del data['price']

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19              1
# 1                MANUAL    Convertible           28        19              1
# 2                MANUAL          Coupe           28        20              0
# 3                MANUAL          Coupe           28        18              0
# 4                MANUAL    Convertible           28        18              0
# ...                 ...            ...          ...       ...            ...
# 11909         AUTOMATIC  4dr Hatchback           23        16              1
# 11910         AUTOMATIC  4dr Hatchback           23        16              1
# 11911         AUTOMATIC  4dr Hatchback           23        16              1
# 11912         AUTOMATIC  4dr Hatchback           23        16              1
# 11913         AUTOMATIC          Sedan           26        17              0
#
# [11914 rows x 10 columns]

# %% [markdown]
# #### Split the data
# #### Split your data in train/val/test sets with 60%/20%/20% distribution.
# #### Use Scikit-Learn for that (the train_test_split function) and set the seed to 42.
# #### Make sure that the target value (price) is not in your dataframe.

# %%
from sklearn.model_selection import train_test_split

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19              1
# 1                MANUAL    Convertible           28        19              1
# 2                MANUAL          Coupe           28        20              0
# 3                MANUAL          Coupe           28        18              0
# 4                MANUAL    Convertible           28        18              0
# ...                 ...            ...          ...       ...            ...
# 11909         AUTOMATIC  4dr Hatchback           23        16              1
# 11910         AUTOMATIC  4dr Hatchback           23        16              1
# 11911         AUTOMATIC  4dr Hatchback           23        16              1
# 11912         AUTOMATIC  4dr Hatchback           23        16              1
# 11913         AUTOMATIC          Sedan           26        17              0
#
# [11914 rows x 10 columns]

# %%
data_full_train, data_test = train_test_split(data, test_size=0.2, random_state=42)
data_train, data_val = train_test_split(data_full_train, test_size = 0.25, random_state = 42)

# %%
len(data_train),len(data_val),len(data_test),len(data)
# Out:
# (7148, 2383, 2383, 11914)

# %%
data_train = data_train.reset_index(drop=True)
data_test = data_test.reset_index(drop=True)
data_val = data_val.reset_index(drop=True)


y_train = data_train.above_average.values
y_val = data_val.above_average.values
y_test = data_test.above_average.values

# %%
del data_train['above_average']
del data_val['above_average']
del data_test['above_average']

# %% [markdown]
# #### Question 3
# #### Calculate the mutual information score between above_average and other categorical variables in our dataset. Use the training set only.
# #### Round the scores to 2 decimals using round(score, 2).
# #### Which of these variables has the lowest mutual information score?

# %%
from sklearn.metrics import mutual_info_score

# %%
categorical_features = ['make','model','transmission_type','vehicle_style']

# %%
def mutual_info_above_average_score(series):
    return round(mutual_info_score(series, data_full_train.above_average),2)

# %%
mutual_info = data_full_train[categorical_features].apply(mutual_info_above_average_score)
mutual_info.sort_values(ascending=True)
# Out:
# transmission_type    0.02
# vehicle_style        0.08
# make                 0.24
# model                0.46
# dtype: float64

# %% [markdown]
# #### Question 4
# #### Now let's train a logistic regression.
# #### Remember that we have several categorical variables in the dataset. Include them using one-hot encoding.
# #### Fit the model on the training dataset.
# #### To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
# #### model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
# #### Calculate the accuracy on the validation dataset and round it to 2 decimal digits.
# #### What accuracy did you get?

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dv = DictVectorizer(sparse = False)

# %%
train_dict = data_train[categorical_features + numerical_features].to_dict(orient= 'records')
X_train = dv.fit_transform(train_dict)

val_dict = data_val[categorical_features + numerical_features].to_dict(orient = 'records')
X_val = dv.transform(val_dict)

# %%
X_train.shape
# Out:
# (7148, 943)

# %%
X_train[1]
# Out:
# array([1.700e+01, 6.000e+00, 2.760e+02, 2.100e+01, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        2.009e+03])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
val_pred = model.predict(X_val)
val_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 1])

# %%
val_accuracy = (val_pred == y_val).mean()
round(val_accuracy,2)
# Out:
# 0.95

# %% [markdown]
# #### Question 5
# #### Let's find the least useful feature using the feature elimination technique.
# #### Train a model with all these features (using the same parameters as in Q4).
# #### Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# #### For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
# #### Which of following feature has the smallest difference?

# %%
# We already trained a model with all features as seen above; no need to train again

features = numerical_features+categorical_features

from sklearn.linear_model import LogisticRegression

for feature in features:
    ss = features.copy()
    ss.remove(feature)
    train_dict = data_train[ss].to_dict(orient='records')
    
    dv = DictVectorizer(sparse=False)
    X_train = dv.fit_transform(train_dict)
    
    model=LogisticRegression(solver="liblinear",C=1.0,max_iter=1000,random_state=42)
    model.fit(X_train, y_train)
    
    val_dict = data_val[ss].to_dict(orient='records')
    X_val = dv.transform(val_dict)
    
    y_pred = model.predict(X_val)
    
    accuracy = (y_val == y_pred).mean()
    
    
    print('For the model without the feature ' + feature + ': the difference in accuracy is:', val_accuracy-accuracy)
# Out:
# For the model without the feature year: the difference in accuracy is: -0.0025178346621905767
# For the model without the feature engine_hp: the difference in accuracy is: 0.025597985732270234
# For the model without the feature engine_cylinders: the difference in accuracy is: 0.0016785564414603105
# For the model without the feature highway_mpg: the difference in accuracy is: 0.004616030214015909
# For the model without the feature city_mpg: the difference in accuracy is: -0.00041963911036513313
# For the model without the feature make: the difference in accuracy is: 0.007553503986571508
# For the model without the feature model: the difference in accuracy is: 0.025597985732270234
# For the model without the feature transmission_type: the difference in accuracy is: 0.007553503986571508
# For the model without the feature vehicle_style: the difference in accuracy is: 0.01888375996642888

# %% [markdown]
# #### Question 6
# #### For this question, we'll see how to use a linear regression model from Scikit-Learn.
# #### We'll need to use the original column price. Apply the logarithmic transformation to this column.
# #### Fit the Ridge regression model on the training data with a solver 'sag'. Set the seed to 42.
# #### This model also has a parameter alpha. Let's try the following values: [0, 0.01, 0.1, 1, 10].
# #### Round your RMSE scores to 3 decimal digits.
# #### Which of these alphas leads to the best RMSE on the validation set?

# %%
from sklearn.linear_model import Ridge

# %%
data = pd.read_csv('car-price-data.csv')
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11914 rows x 16 columns]

# %%
features = ['Make',
'Model',
'Year',
'Engine HP',
'Engine Cylinders',
'Transmission Type',
'Vehicle Style',
'highway MPG',
'city mpg',
'MSRP']

# %%
data = data[features]

# %%
data.columns= data.columns.str.lower().str.replace(' ', '_')

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg   msrp
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# msrp                  0
# dtype: int64

# %%
data.fillna(0, inplace=True)
# Out:
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\2227532753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.fillna(0, inplace=True)

# %%
data.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# msrp                 0
# dtype: int64

# %%
data.rename(columns={'msrp': 'price'}, inplace=True)
# Out:
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\1422463015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'msrp': 'price'}, inplace=True)

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  price
# 0                MANUAL          Coupe           26        19  46135
# 1                MANUAL    Convertible           28        19  40650
# 2                MANUAL          Coupe           28        20  36350
# 3                MANUAL          Coupe           28        18  29450
# 4                MANUAL    Convertible           28        18  34500
# ...                 ...            ...          ...       ...    ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  46120
# 11910         AUTOMATIC  4dr Hatchback           23        16  56670
# 11911         AUTOMATIC  4dr Hatchback           23        16  50620
# 11912         AUTOMATIC  4dr Hatchback           23        16  50920
# 11913         AUTOMATIC          Sedan           26        17  28995
#
# [11914 rows x 10 columns]

# %%
data['price'] = np.log1p(data['price'])
# Out:
# C:\Users\Fozan\AppData\Local\Temp\ipykernel_16428\124179339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price'] = np.log1p(data['price'])

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg      price
# 0                MANUAL          Coupe           26        19  10.739349
# 1                MANUAL    Convertible           28        19  10.612779
# 2                MANUAL          Coupe           28        20  10.500977
# 3                MANUAL          Coupe           28        18  10.290483
# 4                MANUAL    Convertible           28        18  10.448744
# ...                 ...            ...          ...       ...        ...
# 11909         AUTOMATIC  4dr Hatchback           23        16  10.739024
# 11910         AUTOMATIC  4dr Hatchback           23        16  10.945018
# 11911         AUTOMATIC  4dr Hatchback           23        16  10.832122
# 11912         AUTOMATIC  4dr Hatchback           23        16  10.838031
# 11913         AUTOMATIC          Sedan           26        17  10.274913
#
# [11914 rows x 10 columns]

# %%
def split_dataset_process(df, target):
    df = df.copy()
    
    df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=42)
    df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=42)
    ds = [df_train, df_val, df_test, df_train_full]
    for s in ds:
        s.reset_index(drop=True, inplace=True)
    
    # Get y values
    y_train_full = df_train_full[target].values
    y_train = df_train[target].values
    y_val = df_val[target].values
    y_test = df_test[target].values
    
    # Delete target variable from X set
    del df_train[target]
    del df_val[target]
    del df_test[target]
    
    return [df_train_full, df_train, df_test, df_val, y_train_full, y_train, y_val, y_test]

# %%
df_train_full, df_train, df_test, df_val, y_train_full, y_train, y_val, y_test = split_dataset_process(data, 'price')

# %%
train_dict = df_train[categorical_features + numerical_features].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dict)

# %%
val_dict = df_val[categorical_features + numerical_features].to_dict(orient='records')
X_val = dv.transform(val_dict)

# %%
def rmse(y, y_pred):
    error = y_pred - y
    mse = (error ** 2).mean()
    return np.sqrt(mse)

# %%
for i in [0, 0.01, 0.1, 1, 10]:
    model = Ridge(alpha=i, solver="sag", random_state=42)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    
    score = rmse(y_val, y_pred)

    print(i,':', round(score, 3))
# Out:
# C:\Users\Fozan\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0 : 0.487
# C:\Users\Fozan\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.01 : 0.487
# C:\Users\Fozan\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.1 : 0.487
# C:\Users\Fozan\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 1 : 0.487
# 10 : 0.487
# C:\Users\Fozan\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
